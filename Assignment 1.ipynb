# %% [markdown]
# **1.. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators ?**
#
#  **Ans-**
# * : This a multiply operator
#
# 'hello’ :  It’s a string
#
# -87.8: Float value
#
# - : Subtraction
#
# / : Divide Operator
#
# + : Addition operator
#
# 6: Integer value
#
#
#
#
# **2. What is the difference between string and variable?**
#
# **Ans-**
#
# Variable- It can be a variable which can store any type of a value and allocate the space in the memory
#
# String- It’s a string which is a data type.  Which have alphabetical character
#
#
# **3. Describe three different data forms.**
#
# Ans. These are: integer, string, float
#
#
# **4. What is an expression made up of? What do all expressions do?**
#
# **Ans-**
#
# Expression is a representation of data values. Like
# 6+15 : It is representing the integer value
#
# ’hello’ : It is representing the string value
#
# 16.5*5 : It is representing the float value
#
#
# **5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?**
#
# **Ans-**
#
# Expression is representation of the sentence with any data value such as string, int, float, Boolean, complex. It does not related to the storing of any value. It can be change as per requirement
# While declaration means we have declared the value of by initializing some variable with it like spam=10. Here it indicate that its value will be 10 where ever the spam will use.
#
#
# **6.After running the following code, what does the variable bacon contain?**
# **bacon = 22**
# **bacon + 1**
#
# **Ans-**
#
# 23
#
#
# **7. What should the values of the following two terms be?**
# '**spam' + 'spamspam'**
# '**spam' * 3**
#
# **Ans-**
#
# ‘spamspamspam
#     ‘spamspamspam’
#
#
# **8.Why is eggs a valid variable name while 100 is invalid?**
#
# **Ans-**
#
# It is by convention or you can say it’s a protocol that a name of a variable cannot be start with a integer. That’s why 100 is not a true variable name.
#
#
# **9.What three functions can be used to get the integer, floating-point number, or string version of a value?**
#
# **Ans-**
# String
#
#
# **10.Why does this expression cause an error? How can you fix it?**
# **'I have eaten ' + 99 + ' burritos.'**
#
# **Ans-**
# Type error: Concatenation cannot happen between string and integer data type
